# %%
from cryptography.fernet import Fernet
from pyspark.sql.functions import col, udf, lit
from pyspark.sql.types import StringType
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Criando dados aleatórios
data = [
  ["1", "john", "company 1", 12345],
  ["2", "peter", "company 2", 23423],
  ["3", "bobby", "company 3", None],
  ["4", "tony", "company 2", 77464],
  ["5", "steve", "company 1", 80804],
  ["6", "anna", None, 32432]
]

columns = ['Employee_ID', 'Employee_Name', 'Company_Name', 'Password']

dataframe = spark.createDataFrame(data, columns)
display(dataframe)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_ID</th><th>Employee_Name</th><th>Company_Name</th><th>Password</th></tr></thead><tbody><tr><td>1</td><td>john</td><td>company 1</td><td>12345</td></tr><tr><td>2</td><td>peter</td><td>company 2</td><td>23423</td></tr><tr><td>3</td><td>bobby</td><td>company 3</td><td>null</td></tr><tr><td>4</td><td>tony</td><td>company 2</td><td>77464</td></tr><tr><td>5</td><td>steve</td><td>company 1</td><td>80804</td></tr><tr><td>6</td><td>anna</td><td>null</td><td>32432</td></tr></tbody></table></div>

# %%
# Guarde a chave em um lugar seguro
key = Fernet.generate_key()

# Função para encriptar
def encrypt_val(text, MASTER_KEY):
    
    if not text:
      # Se o texto for null, retorna vazio
      return
    else:
      # Transformando em string
      text = str(clear_text)
    
    # Chave para encriptar
    f = Fernet(MASTER_KEY)
    
    # Tranformando texto em bytes
    text_b = bytes(text, 'utf-8')
    
    # Encriptando
    text = f.encrypt(clear_text_b)
    
    # Passando para ascii
    cipher_text = str(cipher_text.decode('ascii'))
    
    return cipher_text

def decrypt_val(cipher_text, MASTER_KEY):
  
    if not cipher_text:
      # Se o texto for null, retorna vazio
      return
    else:
      # Transformando em string
      cipher_text = str(cipher_text)
    
    # Chave para decriptar
    f = Fernet(MASTER_KEY)
    
    # Decriptando
    clear_val = f.decrypt(cipher_text.encode()).decode()
    
    return clear_val
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Função para usar em colunas do dataframe
encrypt = udf(encrypt_val, StringType())
decrypt = udf(decrypt_val, StringType())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Encriptando coluna que ja é string
encrypted = dataframe.withColumn("Company_Name", encrypt(col("Company_Name"),lit(key)))
display(encrypted)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_ID</th><th>Employee_Name</th><th>Company_Name</th><th>Password</th></tr></thead><tbody><tr><td>1</td><td>john</td><td>gAAAAABg0jo5jpPRlbz6vYP2ZcEgz_phXDbx9Z_-3ug1etVdSpnSL4tJp3m3wm5BZ0u1QOdHfZolnFenrgAs9KsNGoXXC6Xxbg==</td><td>12345</td></tr><tr><td>2</td><td>peter</td><td>gAAAAABg0jo5YZ_s8feDklpC7jQzek4KzjRjI-ULrYjaHu67I8anFfx8ofDKYN2FVVonIefQE3P25uObXsGi898Fhp2zJcjACg==</td><td>23423</td></tr><tr><td>3</td><td>bobby</td><td>gAAAAABg0jo5B9jBARP9kn_hU1EQt07DBVcLp_rIj1zv98jXJKeWAdfkiZsY9agrTUpNTzB0uaEsrlanxN-dKraF6cgxA6uZ8A==</td><td>null</td></tr><tr><td>4</td><td>tony</td><td>gAAAAABg0jo5-NsYwEfzBn3CV6E93NAUwtXrFfrCdZR6oHVkNwu423HSRfm1sVmqvgYhr6ozk-s6iU2sXIZFyNNfRF2mlWxbRg==</td><td>77464</td></tr><tr><td>5</td><td>steve</td><td>gAAAAABg0jo5LfTKOdpXXpBHYJGYIub7cbW12LuNV3VGRHIPds0rOljOJ4LzVaz3Rqwfp_YM0A32KUIDyXt9euO2UKk8RZASYA==</td><td>80804</td></tr><tr><td>6</td><td>anna</td><td>null</td><td>32432</td></tr></tbody></table></div>

# %%
# Decriptando coluna que ja é string
decrypted = encrypted.withColumn("Company_Name", decrypt(col("Company_Name"),lit(key)))
display(decrypted)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_ID</th><th>Employee_Name</th><th>Company_Name</th><th>Password</th></tr></thead><tbody><tr><td>1</td><td>john</td><td>company 1</td><td>12345</td></tr><tr><td>2</td><td>peter</td><td>company 2</td><td>23423</td></tr><tr><td>3</td><td>bobby</td><td>company 3</td><td>null</td></tr><tr><td>4</td><td>tony</td><td>company 2</td><td>77464</td></tr><tr><td>5</td><td>steve</td><td>company 1</td><td>80804</td></tr><tr><td>6</td><td>anna</td><td>null</td><td>32432</td></tr></tbody></table></div>

# %%
# Encriptando coluna que é só number
encryptedNumber = dataframe.withColumn("Password", encrypt(col("Password"),lit(key)))
display(encryptedNumber)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_ID</th><th>Employee_Name</th><th>Company_Name</th><th>Password</th></tr></thead><tbody><tr><td>1</td><td>john</td><td>company 1</td><td>gAAAAABg0jo8O64S6mYoXBgK1PCzk6Wc5UJW6FxYFwSDhRCuVJerNeU87cvsqja81DkOJbruerL56j88s5Ul6nsfDYGn1qrl_A==</td></tr><tr><td>2</td><td>peter</td><td>company 2</td><td>gAAAAABg0jo8cUTL_Vl5zUE8kizpDP9Z_QVKAYG5F-6A1iXagx-K4Yzy4LzUxJYXNiIc4x0wiqkQjaF7pKw_YHP9-ZPTiLH5Vg==</td></tr><tr><td>3</td><td>bobby</td><td>company 3</td><td>null</td></tr><tr><td>4</td><td>tony</td><td>company 2</td><td>gAAAAABg0jo8j4b99HGPSOxePcQLnazH928nNMbUkErKNRkZFbDZolv32WBIonu6pIFLuUFzb4S1tv4aHheSORszZGV1d6ZHMA==</td></tr><tr><td>5</td><td>steve</td><td>company 1</td><td>gAAAAABg0jo8Ufvva-f45Yy96OyZ9y8gIGhiIrf1s2PWqLdgH2KJ5ZEoLcCIVtEx-0LA4nK7P_KcoDmsYOz_HbbHwgNobNSrqg==</td></tr><tr><td>6</td><td>anna</td><td>null</td><td>gAAAAABg0jo8gd_mGlyPQBHevS7LfcD44nhSJNlWHJkftC_Sh3rM8_7hogs9djgPCQe8usp2ElOCSYl9lF5e7Zee_F6BB_mMWw==</td></tr></tbody></table></div>

# %%
# Decriptando coluna que é number
decryptedNumber = encryptedNumber.withColumn("Password", decrypt(col("Password"),lit(key)))
display(decryptedNumber)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Employee_ID</th><th>Employee_Name</th><th>Company_Name</th><th>Password</th></tr></thead><tbody><tr><td>1</td><td>john</td><td>company 1</td><td>12345</td></tr><tr><td>2</td><td>peter</td><td>company 2</td><td>23423</td></tr><tr><td>3</td><td>bobby</td><td>company 3</td><td>null</td></tr><tr><td>4</td><td>tony</td><td>company 2</td><td>77464</td></tr><tr><td>5</td><td>steve</td><td>company 1</td><td>80804</td></tr><tr><td>6</td><td>anna</td><td>null</td><td>32432</td></tr></tbody></table></div>
